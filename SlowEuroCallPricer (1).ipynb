# %%
import matplotlib.pyplot as plt #Importing required libraries 
import numpy as np 
import scipy as sc 
from scipy.stats import norm 
import math

# %%
S_0 = float(input("Enter the current spot price: ")) #Initializing our variables 
K = float(input("Enter the strike price: "))
T = float(input("Enter the time to maturity: ")) 
sigma = float(input("Enter the current volatility: ")) 
r = float(input("Enter a \'risk free'\ interest rate: ")) 
N = int(input("Enter the number of timesteps:"))                                 #So we can let the time steps vary 
print(N) 



print()
print() 
print() 
print() 








d1 = ((np.log(S_0/K)) + (((r + sigma**2/2)*T))) / (sigma*np.sqrt(T))   #Calibrating the Black Scholes solution fot the call price
print("d1 according to Black-Scholes is",d1)
d2 = d1 - (sigma*np.sqrt(T))
print("d2 according to Black-Scholes is",d2)
C_t = S_0*norm.cdf(d1) - K*np.exp(-r*T)*norm.cdf(d2)



print()
print() 
print() 
print() 






print("The theoretical call price according to the black-scholes model is",C_t, "dollars")  #Price according to black scholes model 


def eurocall(S_0, K, T, r, N):                                  #Defining a function to price the option
    dt = (T/N)                                                  #Discretizing the timesteps
    u =  np.exp(sigma*np.sqrt(dt) )                             #Values of u&d from the CRR formula
    print("u is", u)
    d = 1/u
    print("d is", d)
    p_q = (np.exp(r*dt)-d)/(u-d)                          #Risk-neutral probability 
    print("The risk neutral probability is", p_q)
    
    S_m = np.zeros(N+1)                                          #Stock prices at maturity dates from the binomial tree 
    S_m[0] = S_0*d**N                                           #Initializes the maturity prices as a vector of zeroes, then updates them by the growth factor u/d
    for x in range(1,N+1): 
        S_m[x] = S_m[x-1]*u/d                                    #Zig-zagging through the tree  
        print('The stock price in step', {x}, 'is', S_m[x])                  #Annoying cause it prints a lot but its nice to see the prices at every step
    
    EC_t = np.zeros(N+1)                                                     #Call prices at maturity dates 
    for x in range(0,N+1):  
        EC_t[x] = max(0, S_m[x]-K)
        print('The euro-style call price at step', {x}, 'is', EC_t[x])
    
    for y in range(N,0, -1):                                                    #Looping backward, descending through the price tree 
        for x in range(0,y): 
            EC_t[x] = np.exp(-r*dt) * (p_q*EC_t[x+1] + (1-p_q)*EC_t[x])  #Call value at each node working backward is the discounted risk neutral expected value of the other nodes 
            
    return EC_t[0]


print()
print() 
print() 
print() 


                                        


print('The European-Style call price right now should be:', "$", eurocall(S_0, K, T, r, N ) ) 

print()
print() 
print() 
print() 


print("The error with ", N, "steps is", abs(C_t - eurocall(S_0, K, T, r, N )))           #Error Measurement 

#At ten thousand steps this for loop method is extremely slow, so vectorization if we wanted to implement effectively this is smarter 


EP_t = C_t - S_0 + K*np.exp(-r*T) # Using Put-Call parity to obtain the put price right now 

print("The put price with same maturity is:", EP_t)






#Doing some hedging after we get the prices 
print() 
print() 
print() 
print() 

delta_call = norm.cdf(d1)
print("Current delta of the call is:",delta_call)
gamma_call = (1/(S_0*np.sqrt(2*math.pi*T)))*np.exp(-d1**2/2)
print("Current gamma of the call is: ", gamma_call)
# Out:
# Enter the current spot price: 76.28
# Enter the strike price: 77
# Enter the time to maturity: 0.08333
# Enter the current volatility: 0.008
# Enter a 'risk free'\ interest rate: 0.0354
# Enter the number of timesteps:100
# 100
#
#
#
#
# d1 according to Black-Scholes is -2.7895636977118277
# d2 according to Black-Scholes is -2.7918730526001028
#
#
#
#
# The theoretical call price according to the black-scholes model is 0.00013875581368663625 dollars
#
#
#
#
# u is 1.0002309621564802
# d is 0.99976909117472
# The risk neutral probability is 0.5638113037151548
# The stock price in step {1} is 74.573044104342
# The stock price in step {2} is 74.60749518449377
# The stock price in step {3} is 74.64196218027482
# The stock price in step {4} is 74.67644509903779
# The stock price in step {5} is 74.71094394813878
# The stock price in step {6} is 74.74545873493722
# The stock price in step {7} is 74.77998946679597
# The stock price in step {8} is 74.8145361510813
# The stock price in step {9} is 74.84909879516287
# The stock price in step {10} is 74.88367740641377
# The stock price in step {11} is 74.91827199221045
# The stock price in step {12} is 74.9528825599328
# The stock price in step {13} is 74.98750911696413
# The stock price in step {14} is 75.02215167069112
# The stock price in step {15} is 75.05681022850389
# The stock price in step {16} is 75.09148479779599
# The stock price in step {17} is 75.12617538596434
# The stock price in step {18} is 75.16088200040932
# The stock price in step {19} is 75.1956046485347
# The stock price in step {20} is 75.2303433377477
# The stock price in step {21} is 75.26509807545891
# The stock price in step {22} is 75.2998688690824
# The stock price in step {23} is 75.33465572603566
# The stock price in step {24} is 75.36945865373956
# The stock price in step {25} is 75.40427765961844
# The stock price in step {26} is 75.43911275110007
# The stock price in step {27} is 75.47396393561561
# The stock price in step {28} is 75.5088312205997
# The stock price in step {29} is 75.5437146134904
# The stock price in step {30} is 75.57861412172919
# The stock price in step {31} is 75.61352975276101
# The stock price in step {32} is 75.64846151403424
# The stock price in step {33} is 75.68340941300066
# The stock price in step {34} is 75.71837345711556
# The stock price in step {35} is 75.75335365383762
# The stock price in step {36} is 75.78835001062899
# The stock price in step {37} is 75.82336253495525
# The stock price in step {38} is 75.85839123428543
# The stock price in step {39} is 75.89343611609205
# The stock price in step {40} is 75.92849718785104
# The stock price in step {41} is 75.96357445704179
# The stock price in step {42} is 75.99866793114715
# The stock price in step {43} is 76.03377761765344
# The stock price in step {44} is 76.06890352405043
# The stock price in step {45} is 76.10404565783132
# The stock price in step {46} is 76.13920402649283
# The stock price in step {47} is 76.17437863753511
# The stock price in step {48} is 76.20956949846176
# The stock price in step {49} is 76.24477661677987
# The stock price in step {50} is 76.28
# The stock price in step {51} is 76.31523965563615
# The stock price in step {52} is 76.35049559120583
# The stock price in step {53} is 76.38576781423001
# The stock price in step {54} is 76.42105633223312
# The stock price in step {55} is 76.45636115274307
# The stock price in step {56} is 76.49168228329125
# The stock price in step {57} is 76.52701973141257
# The stock price in step {58} is 76.56237350464535
# The stock price in step {59} is 76.59774361053144
# The stock price in step {60} is 76.63313005661614
# The stock price in step {61} is 76.66853285044829
# The stock price in step {62} is 76.70395199958016
# The stock price in step {63} is 76.73938751156754
# The stock price in step {64} is 76.7748393939697
# The stock price in step {65} is 76.8103076543494
# The stock price in step {66} is 76.84579230027293
# The stock price in step {67} is 76.88129333931002
# The stock price in step {68} is 76.91681077903394
# The stock price in step {69} is 76.9523446270214
# The stock price in step {70} is 76.9878948908527
# The stock price in step {71} is 77.02346157811157
# The stock price in step {72} is 77.05904469638526
# The stock price in step {73} is 77.09464425326453
# The stock price in step {74} is 77.13026025634367
# The stock price in step {75} is 77.16589271322044
# The stock price in step {76} is 77.20154163149614
# The stock price in step {77} is 77.23720701877556
# The stock price in step {78} is 77.272888882667
# The stock price in step {79} is 77.30858723078231
# The stock price in step {80} is 77.34430207073683
# The stock price in step {81} is 77.38003341014941
# The stock price in step {82} is 77.41578125664243
# The stock price in step {83} is 77.4515456178418
# The stock price in step {84} is 77.48732650137694
# The stock price in step {85} is 77.5231239148808
# The stock price in step {86} is 77.55893786598986
# The stock price in step {87} is 77.59476836234413
# The stock price in step {88} is 77.63061541158713
# The stock price in step {89} is 77.66647902136593
# The stock price in step {90} is 77.70235919933113
# The stock price in step {91} is 77.73825595313686
# The stock price in step {92} is 77.7741692904408
# The stock price in step {93} is 77.81009921890414
# The stock price in step {94} is 77.84604574619162
# The stock price in step {95} is 77.88200887997155
# The stock price in step {96} is 77.91798862791573
# The stock price in step {97} is 77.95398499769955
# The stock price in step {98} is 77.98999799700192
# The stock price in step {99} is 78.02602763350531
# The stock price in step {100} is 78.06207391489573
# The euro-style call price at step {0} is 0.0
# The euro-style call price at step {1} is 0.0
# The euro-style call price at step {2} is 0.0
# The euro-style call price at step {3} is 0.0
# The euro-style call price at step {4} is 0.0
# The euro-style call price at step {5} is 0.0
# The euro-style call price at step {6} is 0.0
# The euro-style call price at step {7} is 0.0
# The euro-style call price at step {8} is 0.0
# The euro-style call price at step {9} is 0.0
# The euro-style call price at step {10} is 0.0
# The euro-style call price at step {11} is 0.0
# The euro-style call price at step {12} is 0.0
# The euro-style call price at step {13} is 0.0
# The euro-style call price at step {14} is 0.0
# The euro-style call price at step {15} is 0.0
# The euro-style call price at step {16} is 0.0
# The euro-style call price at step {17} is 0.0
# The euro-style call price at step {18} is 0.0
# The euro-style call price at step {19} is 0.0
# The euro-style call price at step {20} is 0.0
# The euro-style call price at step {21} is 0.0
# The euro-style call price at step {22} is 0.0
# The euro-style call price at step {23} is 0.0
# The euro-style call price at step {24} is 0.0
# The euro-style call price at step {25} is 0.0
# The euro-style call price at step {26} is 0.0
# The euro-style call price at step {27} is 0.0
# The euro-style call price at step {28} is 0.0
# The euro-style call price at step {29} is 0.0
# The euro-style call price at step {30} is 0.0
# The euro-style call price at step {31} is 0.0
# The euro-style call price at step {32} is 0.0
# The euro-style call price at step {33} is 0.0
# The euro-style call price at step {34} is 0.0
# The euro-style call price at step {35} is 0.0
# The euro-style call price at step {36} is 0.0
# The euro-style call price at step {37} is 0.0
# The euro-style call price at step {38} is 0.0
# The euro-style call price at step {39} is 0.0
# The euro-style call price at step {40} is 0.0
# The euro-style call price at step {41} is 0.0
# The euro-style call price at step {42} is 0.0
# The euro-style call price at step {43} is 0.0
# The euro-style call price at step {44} is 0.0
# The euro-style call price at step {45} is 0.0
# The euro-style call price at step {46} is 0.0
# The euro-style call price at step {47} is 0.0
# The euro-style call price at step {48} is 0.0
# The euro-style call price at step {49} is 0.0
# The euro-style call price at step {50} is 0.0
# The euro-style call price at step {51} is 0.0
# The euro-style call price at step {52} is 0.0
# The euro-style call price at step {53} is 0.0
# The euro-style call price at step {54} is 0.0
# The euro-style call price at step {55} is 0.0
# The euro-style call price at step {56} is 0.0
# The euro-style call price at step {57} is 0.0
# The euro-style call price at step {58} is 0.0
# The euro-style call price at step {59} is 0.0
# The euro-style call price at step {60} is 0.0
# The euro-style call price at step {61} is 0.0
# The euro-style call price at step {62} is 0.0
# The euro-style call price at step {63} is 0.0
# The euro-style call price at step {64} is 0.0
# The euro-style call price at step {65} is 0.0
# The euro-style call price at step {66} is 0.0
# The euro-style call price at step {67} is 0.0
# The euro-style call price at step {68} is 0.0
# The euro-style call price at step {69} is 0.0
# The euro-style call price at step {70} is 0.0
# The euro-style call price at step {71} is 0.023461578111565018
# The euro-style call price at step {72} is 0.05904469638525711
# The euro-style call price at step {73} is 0.09464425326453352
# The euro-style call price at step {74} is 0.130260256343675
# The euro-style call price at step {75} is 0.16589271322044397
# The euro-style call price at step {76} is 0.20154163149614135
# The euro-style call price at step {77} is 0.23720701877556394
# The euro-style call price at step {78} is 0.2728888826670044
# The euro-style call price at step {79} is 0.3085872307823081
# The euro-style call price at step {80} is 0.3443020707368305
# The euro-style call price at step {81} is 0.3800334101494087
# The euro-style call price at step {82} is 0.4157812566424326
# The euro-style call price at step {83} is 0.451545617841802
# The euro-style call price at step {84} is 0.4873265013769412
# The euro-style call price at step {85} is 0.5231239148807987
# The euro-style call price at step {86} is 0.5589378659898614
# The euro-style call price at step {87} is 0.5947683623441264
# The euro-style call price at step {88} is 0.6306154115871294
# The euro-style call price at step {89} is 0.6664790213659302
# The euro-style call price at step {90} is 0.7023591993311271
# The euro-style call price at step {91} is 0.7382559531368571
# The euro-style call price at step {92} is 0.7741692904407955
# The euro-style call price at step {93} is 0.810099218904142
# The euro-style call price at step {94} is 0.8460457461916207
# The euro-style call price at step {95} is 0.8820088799715506
# The euro-style call price at step {96} is 0.917988627915733
# The euro-style call price at step {97} is 0.9539849976995498
# The euro-style call price at step {98} is 0.9899979970019217
# The euro-style call price at step {99} is 1.0260276335053078
# The euro-style call price at step {100} is 1.062073914895734
# The European-Style call price right now should be: $ 0.00010541046435093719
#
#
#
#
# u is 1.0002309621564802
# d is 0.99976909117472
# The risk neutral probability is 0.5638113037151548
# The stock price in step {1} is 74.573044104342
# The stock price in step {2} is 74.60749518449377
# The stock price in step {3} is 74.64196218027482
# The stock price in step {4} is 74.67644509903779
# The stock price in step {5} is 74.71094394813878
# The stock price in step {6} is 74.74545873493722
# The stock price in step {7} is 74.77998946679597
# The stock price in step {8} is 74.8145361510813
# The stock price in step {9} is 74.84909879516287
# The stock price in step {10} is 74.88367740641377
# The stock price in step {11} is 74.91827199221045
# The stock price in step {12} is 74.9528825599328
# The stock price in step {13} is 74.98750911696413
# The stock price in step {14} is 75.02215167069112
# The stock price in step {15} is 75.05681022850389
# The stock price in step {16} is 75.09148479779599
# The stock price in step {17} is 75.12617538596434
# The stock price in step {18} is 75.16088200040932
# The stock price in step {19} is 75.1956046485347
# The stock price in step {20} is 75.2303433377477
# The stock price in step {21} is 75.26509807545891
# The stock price in step {22} is 75.2998688690824
# The stock price in step {23} is 75.33465572603566
# The stock price in step {24} is 75.36945865373956
# The stock price in step {25} is 75.40427765961844
# The stock price in step {26} is 75.43911275110007
# The stock price in step {27} is 75.47396393561561
# The stock price in step {28} is 75.5088312205997
# The stock price in step {29} is 75.5437146134904
# The stock price in step {30} is 75.57861412172919
# The stock price in step {31} is 75.61352975276101
# The stock price in step {32} is 75.64846151403424
# The stock price in step {33} is 75.68340941300066
# The stock price in step {34} is 75.71837345711556
# The stock price in step {35} is 75.75335365383762
# The stock price in step {36} is 75.78835001062899
# The stock price in step {37} is 75.82336253495525
# The stock price in step {38} is 75.85839123428543
# The stock price in step {39} is 75.89343611609205
# The stock price in step {40} is 75.92849718785104
# The stock price in step {41} is 75.96357445704179
# The stock price in step {42} is 75.99866793114715
# The stock price in step {43} is 76.03377761765344
# The stock price in step {44} is 76.06890352405043
# The stock price in step {45} is 76.10404565783132
# The stock price in step {46} is 76.13920402649283
# The stock price in step {47} is 76.17437863753511
# The stock price in step {48} is 76.20956949846176
# The stock price in step {49} is 76.24477661677987
# The stock price in step {50} is 76.28
# The stock price in step {51} is 76.31523965563615
# The stock price in step {52} is 76.35049559120583
# The stock price in step {53} is 76.38576781423001
# The stock price in step {54} is 76.42105633223312
# The stock price in step {55} is 76.45636115274307
# The stock price in step {56} is 76.49168228329125
# The stock price in step {57} is 76.52701973141257
# The stock price in step {58} is 76.56237350464535
# The stock price in step {59} is 76.59774361053144
# The stock price in step {60} is 76.63313005661614
# The stock price in step {61} is 76.66853285044829
# The stock price in step {62} is 76.70395199958016
# The stock price in step {63} is 76.73938751156754
# The stock price in step {64} is 76.7748393939697
# The stock price in step {65} is 76.8103076543494
# The stock price in step {66} is 76.84579230027293
# The stock price in step {67} is 76.88129333931002
# The stock price in step {68} is 76.91681077903394
# The stock price in step {69} is 76.9523446270214
# The stock price in step {70} is 76.9878948908527
# The stock price in step {71} is 77.02346157811157
# The stock price in step {72} is 77.05904469638526
# The stock price in step {73} is 77.09464425326453
# The stock price in step {74} is 77.13026025634367
# The stock price in step {75} is 77.16589271322044
# The stock price in step {76} is 77.20154163149614
# The stock price in step {77} is 77.23720701877556
# The stock price in step {78} is 77.272888882667
# The stock price in step {79} is 77.30858723078231
# The stock price in step {80} is 77.34430207073683
# The stock price in step {81} is 77.38003341014941
# The stock price in step {82} is 77.41578125664243
# The stock price in step {83} is 77.4515456178418
# The stock price in step {84} is 77.48732650137694
# The stock price in step {85} is 77.5231239148808
# The stock price in step {86} is 77.55893786598986
# The stock price in step {87} is 77.59476836234413
# The stock price in step {88} is 77.63061541158713
# The stock price in step {89} is 77.66647902136593
# The stock price in step {90} is 77.70235919933113
# The stock price in step {91} is 77.73825595313686
# The stock price in step {92} is 77.7741692904408
# The stock price in step {93} is 77.81009921890414
# The stock price in step {94} is 77.84604574619162
# The stock price in step {95} is 77.88200887997155
# The stock price in step {96} is 77.91798862791573
# The stock price in step {97} is 77.95398499769955
# The stock price in step {98} is 77.98999799700192
# The stock price in step {99} is 78.02602763350531
# The stock price in step {100} is 78.06207391489573
# The euro-style call price at step {0} is 0.0
# The euro-style call price at step {1} is 0.0
# The euro-style call price at step {2} is 0.0
# The euro-style call price at step {3} is 0.0
# The euro-style call price at step {4} is 0.0
# The euro-style call price at step {5} is 0.0
# The euro-style call price at step {6} is 0.0
# The euro-style call price at step {7} is 0.0
# The euro-style call price at step {8} is 0.0
# The euro-style call price at step {9} is 0.0
# The euro-style call price at step {10} is 0.0
# The euro-style call price at step {11} is 0.0
# The euro-style call price at step {12} is 0.0
# The euro-style call price at step {13} is 0.0
# The euro-style call price at step {14} is 0.0
# The euro-style call price at step {15} is 0.0
# The euro-style call price at step {16} is 0.0
# The euro-style call price at step {17} is 0.0
# The euro-style call price at step {18} is 0.0
# The euro-style call price at step {19} is 0.0
# The euro-style call price at step {20} is 0.0
# The euro-style call price at step {21} is 0.0
# The euro-style call price at step {22} is 0.0
# The euro-style call price at step {23} is 0.0
# The euro-style call price at step {24} is 0.0
# The euro-style call price at step {25} is 0.0
# The euro-style call price at step {26} is 0.0
# The euro-style call price at step {27} is 0.0
# The euro-style call price at step {28} is 0.0
# The euro-style call price at step {29} is 0.0
# The euro-style call price at step {30} is 0.0
# The euro-style call price at step {31} is 0.0
# The euro-style call price at step {32} is 0.0
# The euro-style call price at step {33} is 0.0
# The euro-style call price at step {34} is 0.0
# The euro-style call price at step {35} is 0.0
# The euro-style call price at step {36} is 0.0
# The euro-style call price at step {37} is 0.0
# The euro-style call price at step {38} is 0.0
# The euro-style call price at step {39} is 0.0
# The euro-style call price at step {40} is 0.0
# The euro-style call price at step {41} is 0.0
# The euro-style call price at step {42} is 0.0
# The euro-style call price at step {43} is 0.0
# The euro-style call price at step {44} is 0.0
# The euro-style call price at step {45} is 0.0
# The euro-style call price at step {46} is 0.0
# The euro-style call price at step {47} is 0.0
# The euro-style call price at step {48} is 0.0
# The euro-style call price at step {49} is 0.0
# The euro-style call price at step {50} is 0.0
# The euro-style call price at step {51} is 0.0
# The euro-style call price at step {52} is 0.0
# The euro-style call price at step {53} is 0.0
# The euro-style call price at step {54} is 0.0
# The euro-style call price at step {55} is 0.0
# The euro-style call price at step {56} is 0.0
# The euro-style call price at step {57} is 0.0
# The euro-style call price at step {58} is 0.0
# The euro-style call price at step {59} is 0.0
# The euro-style call price at step {60} is 0.0
# The euro-style call price at step {61} is 0.0
# The euro-style call price at step {62} is 0.0
# The euro-style call price at step {63} is 0.0
# The euro-style call price at step {64} is 0.0
# The euro-style call price at step {65} is 0.0
# The euro-style call price at step {66} is 0.0
# The euro-style call price at step {67} is 0.0
# The euro-style call price at step {68} is 0.0
# The euro-style call price at step {69} is 0.0
# The euro-style call price at step {70} is 0.0
# The euro-style call price at step {71} is 0.023461578111565018
# The euro-style call price at step {72} is 0.05904469638525711
# The euro-style call price at step {73} is 0.09464425326453352
# The euro-style call price at step {74} is 0.130260256343675
# The euro-style call price at step {75} is 0.16589271322044397
# The euro-style call price at step {76} is 0.20154163149614135
# The euro-style call price at step {77} is 0.23720701877556394
# The euro-style call price at step {78} is 0.2728888826670044
# The euro-style call price at step {79} is 0.3085872307823081
# The euro-style call price at step {80} is 0.3443020707368305
# The euro-style call price at step {81} is 0.3800334101494087
# The euro-style call price at step {82} is 0.4157812566424326
# The euro-style call price at step {83} is 0.451545617841802
# The euro-style call price at step {84} is 0.4873265013769412
# The euro-style call price at step {85} is 0.5231239148807987
# The euro-style call price at step {86} is 0.5589378659898614
# The euro-style call price at step {87} is 0.5947683623441264
# The euro-style call price at step {88} is 0.6306154115871294
# The euro-style call price at step {89} is 0.6664790213659302
# The euro-style call price at step {90} is 0.7023591993311271
# The euro-style call price at step {91} is 0.7382559531368571
# The euro-style call price at step {92} is 0.7741692904407955
# The euro-style call price at step {93} is 0.810099218904142
# The euro-style call price at step {94} is 0.8460457461916207
# The euro-style call price at step {95} is 0.8820088799715506
# The euro-style call price at step {96} is 0.917988627915733
# The euro-style call price at step {97} is 0.9539849976995498
# The euro-style call price at step {98} is 0.9899979970019217
# The euro-style call price at step {99} is 1.0260276335053078
# The euro-style call price at step {100} is 1.062073914895734
# The error with  100 steps is 3.334534933569907e-05
#
#
#
#
# Current delta of the call is: 0.002638955657610196
# Current gamma of the call is:  0.0003701105547116861
