# %%
#Lance William Martin, Mathematical Finance Project 

import matplotlib.pyplot as plt #Importing required libraries 
import numpy as np 
import scipy as sc 
from scipy.stats import norm 
import math

# %%
S_0 = 10 #Initializing our variables 
K = 10
T = 0.25 
sigma = 0.25 
r = 0.02 
N = int(input("Please enter the number of timesteps:"))                                 #So we can let the time steps vary 
print(N) 

d1 = (np.log(S_0/K) + (((r + sigma**2)/2)*T))/(sigma*np.sqrt(T))   #Calibrating the Black Scholes solution fot the call price
print("d1 according to Black-Scholes is",d1)
d2 = (np.log(S_0/K)+ (((r-sigma**2)/2)*T))/(sigma*np.sqrt(T))
print("d2 according to Black-Scholes is",d2)
C_t = S_0*norm.cdf(d1) - K*np.exp(-r*T)*norm.cdf(d2)

print("The theoretical call price according to the black-scholes model is",C_t, "dollars")           #Price according to black scholes model 


def eurocall(S_0, K, T, r, N):                                  #Defining a function to price the option
    dt = (T/N)                                                  #Discretizing the timesteps
    u =  np.exp(sigma*np.sqrt(dt) )                             #Values of u&d from the CRR formula
    print("u is", u)
    d = 1/u
    print("d is", d)
    p_q = (np.exp(r*dt)-d)/(u-d)                          #Risk-neutral probability 
    print("The risk neutral probability is", p_q)
    
    S_m = np.zeros(N+1)                                          #Stock prices at maturity dates from the binomial tree 
    S_m[0] = S_0*d**N                                           #Initializes the maturity prices as a vector of zeroes, then updates them by the growth factor u/d
    for x in range(1,N+1): 
        S_m[x] = S_m[x-1]*u/d
        print('The stock price in step', {x}, 'is', S_m[x])                  #Annoying cause it prints a lot but its nice to see the prices at every step
    
    EC_t = np.zeros(N+1)                                                     #Call prices at maturity dates 
    for x in range(0,N+1):  
        EC_t[x] = max(0, S_m[x]-K)
        print('The euro-style call price at step', {x}, 'is', EC_t[x])
    
    for y in range(N,0, -1):                                                    #Looping backward through the price tree 
        for x in range(0,y): 
            EC_t[x] = np.exp(-r*dt) * (p_q*EC_t[x+1] + (1-p_q)*EC_t[x])           #Call value at each node working backward is the discounted risk neutral expected value of the other nodes 
            
    return EC_t[0]

                                        


print('The European-Style call price right now should be:', "$", eurocall(S_0, K, T, r, N ) ) 

print("The error with ", N, "steps is", abs(C_t - eurocall(S_0, K, T, r, N )))           #Error Measurement 

#At ten thousand steps this for loop method is extremely slow, so vectorization if we wanted to implement effectively this is smarter
# Out:
# Please enter the number of timesteps:10000
# 10000
# The theoretical call price according to the black-scholes model is 0.5223460716078163 dollars
# u is 1.0012507815756226
# d is 0.9987507809245808
# The risk neutral probability is 0.49988750003864035
# The stock price in step {1} is 3.735981460508643e-05
# The stock price in step {2} is 3.745333098837181e-05
# The stock price in step {3} is 3.754708145509779e-05
# The stock price in step {4} is 3.7641066591205085e-05
# The stock price in step {5} is 3.7735286984101106e-05
# The stock price in step {6} is 3.782974322266361e-05
# The stock price in step {7} is 3.79244358972444e-05
# The stock price in step {8} is 3.8019365599673e-05
# The stock price in step {9} is 3.811453292326036e-05
# The stock price in step {10} is 3.8209938462802565e-05
# The stock price in step {11} is 3.8305582814584544e-05
# The stock price in step {12} is 3.8401466576383805e-05
# The stock price in step {13} is 3.8497590347474174e-05
# The stock price in step {14} is 3.859395472862953e-05
# The stock price in step {15} is 3.8690560322127574e-05
# The stock price in step {16} is 3.878740773175358e-05
# The stock price in step {17} is 3.8884497562804166e-05
# The stock price in step {18} is 3.8981830422091096e-05
# The stock price in step {19} is 3.9079406917945055e-05
# The stock price in step {20} is 3.917722766021947e-05
# The stock price in step {21} is 3.927529326029428e-05
# The stock price in step {22} is 3.9373604331079825e-05
# The stock price in step {23} is 3.9472161487020605e-05
# The stock price in step {24} is 3.9570965344099175e-05
# The stock price in step {25} is 3.967001651983996e-05
# The stock price in step {26} is 3.9769315633313124e-05
# The stock price in step {27} is 3.986886330513845e-05
# The stock price in step {28} is 3.9968660157489215e-05
# The stock price in step {29} is 4.006870681409607e-05
# The stock price in step {30} is 4.0169003900250946e-05
# The stock price in step {31} is 4.0269552042810956e-05
# The stock price in step {32} is 4.037035187020232e-05
# The stock price in step {33} is 4.047140401242429e-05
# The stock price in step {34} is 4.057270910105308e-05
# The stock price in step {35} is 4.0674267769245827e-05
# The stock price in step {36} is 4.077608065174453e-05
# The stock price in step {37} is 4.0878148384880044e-05
# The stock price in step {38} is 4.098047160657603e-05
# The stock price in step {39} is 4.108305095635296e-05
# The stock price in step {40} is 4.1185887075332094e-05
# The stock price in step {41} is 4.128898060623952e-05
# The stock price in step {42} is 4.139233219341014e-05
# The stock price in step {43} is 4.149594248279171e-05
# The stock price in step {44} is 4.159981212194887e-05
# The stock price in step {45} is 4.170394176006721e-05
# The stock price in step {46} is 4.1808332047957317e-05
# The stock price in step {47} is 4.191298363805881e-05
# The stock price in step {48} is 4.201789718444448e-05
# The stock price in step {49} is 4.212307334282433e-05
# The stock price in step {50} is 4.222851277054969e-05
# The stock price in step {51} is 4.2334216126617333e-05
# The stock price in step {52} is 4.244018407167357e-05
# The stock price in step {53} is 4.25464172680184e-05
# The stock price in step {54} is 4.265291637960966e-05
# The stock price in step {55} is 4.275968207206713e-05
# The stock price in step {56} is 4.2866715012676744e-05
# The stock price in step {57} is 4.297401587039473e-05
# The stock price in step {58} is 4.30815853158518e-05
# The stock price in step {59} is 4.318942402135733e-05
# The stock price in step {60} is 4.329753266090358e-05
# The stock price in step {61} is 4.34059119101699e-05
# The stock price in step {62} is 4.3514562446526965e-05
# The stock price in step {63} is 4.3623484949040965e-05
# The stock price in step {64} is 4.37326800984779e-05
# The stock price in step {65} is 4.384214857730781e-05
# The stock price in step {66} is 4.395189106970905e-05
# The stock price in step {67} is 4.4061908261572544e-05
# The stock price in step {68} is 4.41722008405061e-05
# The stock price in step {69} is 4.4282769495838706e-05
# The stock price in step {70} is 4.43936149186248e-05
# The stock price in step {71} is 4.450473780164865e-05
# The stock price in step {72} is 4.4616138839428636e-05
# The stock price in step {73} is 4.47278187282216e-05
# The stock price in step {74} is 4.4839778166027216e-05
# The stock price in step {75} is 4.4952017852592335e-05
# The stock price in step {76} is 4.506453848941536e-05
# The stock price in step {77} is 4.5177340779750635e-05
# The stock price in step {78} is 4.529042542861285e-05
# The stock price in step {79} is 4.540379314278142e-05
# The stock price in step {80} is 4.5517444630804924e-05
# The stock price in step {81} is 4.5631380603005544e-05
# The stock price in step {82} is 4.574560177148348e-05
# The stock price in step {83} is 4.586010885012139e-05
# The stock price in step {84} is 4.5974902554588905e-05
# The stock price in step {85} is 4.608998360234704e-05
# The stock price in step {86} is 4.620535271265272e-05
# The stock price in step {87} is 4.632101060656327e-05
# The stock price in step {88} is 4.643695800694089e-05
# The stock price in step {89} is 4.655319563845721e-05
# The stock price in step {90} is 4.666972422759782e-05
# The stock price in step {91} is 4.6786544502666766e-05
# The stock price in step {92} is 4.6903657193791155e-05
# The stock price in step {93} is 4.702106303292569e-05
# The stock price in step {94} is 4.713876275385724e-05
# The stock price in step {95} is 4.725675709220946e-05
# The stock price in step {96} is 4.737504678544732e-05
# The stock price in step {97} is 4.749363257288182e-05
# The stock price in step {98} is 4.761251519567449e-05
# The stock price in step {99} is 4.773169539684213e-05
# The stock price in step {100} is 4.785117392126137e-05
# The stock price in step {101} is 4.797095151567339e-05
# The stock price in step {102} is 4.809102892868854e-05
# The stock price in step {103} is 4.821140691079103e-05
# The stock price in step {104} is 4.833208621434366e-05
# The stock price in step {105} is 4.845306759359246e-05
# The stock price in step {106} is 4.857435180467144e-05
# The stock price in step {107} is 4.869593960560732e-05
# The stock price in step {108} is 4.8817831756324254e-05
# The stock price in step {109} is 4.894002901864858e-05
# The stock price in step {110} is 4.9062532156313575e-05
# The stock price in step {111} is 4.9185341934964254e-05
# The stock price in step {112} is 4.9308459122162146e-05
# The stock price in step {113} is 4.9431884487390056e-05
# The stock price in step {114} is 4.955561880205693e-05
# The stock price in step {115} is 4.967966283950262e-05
# The stock price in step {116} is 4.9804017375002776e-05
# The stock price in step {117} is 4.992868318577365e-05
# The stock price in step {118} is 5.005366105097697e-05
# The stock price in step {119} is 5.017895175172478e-05
# The stock price in step {120} is 5.0304556071084386e-05
# The stock price in step {121} is 5.043047479408319e-05
# The stock price in step {122} is 5.0556708707713624e-05
# The stock price in step {123} is 5.068325860093805e-05
# The stock price in step {124} is 5.0810125264693715e-05
# The stock price in step {125} is 5.093730949189768e-05
# The stock price in step {126} is 5.106481207745179e-05
# The stock price in step {127} is 5.11926338182476e-05
# The stock price in step {128} is 5.132077551317142e-05
# The stock price in step {129} is 5.1449237963109255e-05
# The stock price in step {130} is 5.157802197095184e-05
# The stock price in step {131} is 5.170712834159964e-05
# The stock price in step {132} is 5.183655788196789e-05
# The stock price in step {133} is 5.196631140099165e-05
# The stock price in step {134} is 5.209638970963083e-05
# The stock price in step {135} is 5.222679362087527e-05
# The stock price in step {136} is 5.235752394974986e-05
# The stock price in step {137} is 5.248858151331956e-05
# The stock price in step {138} is 5.2619967130694586e-05
# The stock price in step {139} is 5.2751681623035464e-05
# The stock price in step {140} is 5.2883725813558203e-05
# The stock price in step {141} is 5.3016100527539427e-05
# The stock price in step {142} is 5.3148806592321526e-05
# The stock price in step {143} is 5.3281844837317834e-05
# The stock price in step {144} is 5.3415216094017825e-05
# The stock price in step {145} is 5.354892119599228e-05
# The stock price in step {146} is 5.368296097889852e-05
# The stock price in step {147} is 5.3817336280485625e-05
# The stock price in step {148} is 5.395204794059967e-05
# The stock price in step {149} is 5.408709680118898e-05
# The stock price in step {150} is 5.422248370630935e-05
# The stock price in step {151} is 5.4358209502129393e-05
# The stock price in step {152} is 5.449427503693577e-05
# The stock price in step {153} is 5.463068116113852e-05
# The stock price in step {154} is 5.476742872727636e-05
# The stock price in step {155} is 5.490451859002203e-05
# The stock price in step {156} is 5.504195160618761e-05
# The stock price in step {157} is 5.5179728634729905e-05
# The stock price in step {158} is 5.5317850536755784e-05
# The stock price in step {159} is 5.545631817552759e-05
# The stock price in step {160} is 5.5595132416468516e-05
# The stock price in step {161} is 5.573429412716802e-05
# The stock price in step {162} is 5.5873804177387244e-05
# The stock price in step {163} is 5.601366343906446e-05
# The stock price in step {164} is 5.61538727863205e-05
# The stock price in step {165} is 5.629443309546425e-05
# The stock price in step {166} is 5.64353452449981e-05
# The stock price in step {167} is 5.6576610115623443e-05
# The stock price in step {168} is 5.671822859024617e-05
# The stock price in step {169} is 5.6860201553982225e-05
# The stock price in step {170} is 5.7002529894163075e-05
# The stock price in step {171} is 5.714521450034132e-05
# The stock price in step {172} is 5.728825626429621e-05
# The stock price in step {173} is 5.743165608003924e-05
# The stock price in step {174} is 5.757541484381972e-05
# The stock price in step {175} is 5.77195334541304e-05
# The stock price in step {176} is 5.786401281171305e-05
# The stock price in step {177} is 5.8008853819564134e-05
# The stock price in step {178} is 5.8154057382940426e-05
# The stock price in step {179} is 5.829962440936466e-05
# The stock price in step {180} is 5.844555580863123e-05
# The stock price in step {181} is 5.859185249281186e-05
# The stock price in step {182} is 5.87385153762613e-05
# The stock price in step {183} is 5.888554537562305e-05
# The stock price in step {184} is 5.903294340983508e-05
# The stock price in step {185} is 5.918071040013559e-05
# The stock price in step {186} is 5.932884727006874e-05
# The stock price in step {187} is 5.947735494549046e-05
# The stock price in step {188} is 5.9626234354574193e-05
# The stock price in step {189} is 5.9775486427816744e-05
# The stock price in step {190} is 5.992511209804405e-05
# The stock price in step {191} is 6.0075112300417036e-05
# The stock price in step {192} is 6.0225487972437455e-05
# The stock price in step {193} is 6.037624005395375e-05
# The stock price in step {194} is 6.052736948716692e-05
# The stock price in step {195} is 6.067887721663641e-05
# The stock price in step {196} is 6.0830764189286035e-05
# The stock price in step {197} is 6.0983031354409854e-05
# The stock price in step {198} is 6.113567966367815e-05
# The stock price in step {199} is 6.128871007114335e-05
# The stock price in step {200} is 6.1442123533246e-05
# The stock price in step {201} is 6.159592100882075e-05
# The stock price in step {202} is 6.17501034591023e-05
# The stock price in step {203} is 6.190467184773148e-05
# The stock price in step {204} is 6.205962714076122e-05
# The stock price in step {205} is 6.221497030666262e-05
# The stock price in step {206} is 6.237070231633096e-05
# The stock price in step {207} is 6.25268241430918e-05
# The stock price in step {208} is 6.268333676270709e-05
# The stock price in step {209} is 6.284024115338117e-05
# The stock price in step {210} is 6.299753829576703e-05
# The stock price in step {211} is 6.315522917297231e-05
# The stock price in step {212} is 6.33133147705655e-05
# The stock price in step {213} is 6.34717960765821e-05
# The stock price in step {214} is 6.36306740815308e-05
# The stock price in step {215} is 6.378994977839964e-05
# The stock price in step {216} is 6.394962416266224e-05
# The stock price in step {217} is 6.410969823228402e-05
# The stock price in step {218} is 6.427017298772845e-05
# The stock price in step {219} is 6.443104943196326e-05
# The stock price in step {220} is 6.459232857046677e-05
# The stock price in step {221} is 6.47540114112341e-05
# The stock price in step {222} is 6.491609896478354e-05
# The stock price in step {223} is 6.507859224416283e-05
# The stock price in step {224} is 6.524149226495548e-05
# The stock price in step {225} is 6.540480004528715e-05
# The stock price in step {226} is 6.556851660583203e-05
# The stock price in step {227} is 6.573264296981914e-05
# The stock price in step {228} is 6.589718016303878e-05
# The stock price in step {229} is 6.606212921384894e-05
# The stock price in step {230} is 6.622749115318173e-05
# The stock price in step {231} is 6.63932670145498e-05
# The stock price in step {232} is 6.655945783405285e-05
# The stock price in step {233} is 6.672606465038404e-05
# The stock price in step {234} is 6.68930885048365e-05
# The stock price in step {235} is 6.706053044130987e-05
# The stock price in step {236} is 6.722839150631677e-05
# The stock price in step {237} is 6.739667274898944e-05
# The stock price in step {238} is 6.756537522108618e-05
# The stock price in step {239} is 6.7734499976998e-05
# The stock price in step {240} is 6.790404807375515e-05
# The stock price in step {241} is 6.807402057103381e-05
# The stock price in step {242} is 6.824441853116263e-05
# The stock price in step {243} is 6.841524301912943e-05
# The stock price in step {244} is 6.85864951025878e-05
# The stock price in step {245} is 6.875817585186383e-05
# The stock price in step {246} is 6.893028633996275e-05
# The stock price in step {247} is 6.910282764257568e-05
# The stock price in step {248} is 6.927580083808632e-05
# The stock price in step {249} is 6.944920700757771e-05
# The stock price in step {250} is 6.962304723483896e-05
# The stock price in step {251} is 6.979732260637207e-05
# The stock price in step {252} is 6.997203421139867e-05
# The stock price in step {253} is 7.014718314186688e-05
# The stock price in step {254} is 7.032277049245807e-05
# The stock price in step {255} is 7.049879736059373e-05
# The stock price in step {256} is 7.06752648464424e-05
# The stock price in step {257} is 7.085217405292641e-05
# The stock price in step {258} is 7.102952608572891e-05
# The stock price in step {259} is 7.120732205330065e-05
# The stock price in step {260} is 7.138556306686701e-05
# The stock price in step {261} is 7.156425024043492e-05
# The stock price in step {262} is 7.17433846907998e-05
# The stock price in step {263} is 7.192296753755252e-05
# The stock price in step {264} is 7.210299990308647e-05
# The stock price in step {265} is 7.228348291260453e-05
# The stock price in step {266} is 7.246441769412609e-05
# The stock price in step {267} is 7.264580537849413e-05
# The stock price in step {268} is 7.282764709938227e-05
# The stock price in step {269} is 7.300994399330184e-05
# The stock price in step {270} is 7.319269719960903e-05
# The stock price in step {271} is 7.337590786051197e-05
# The stock price in step {272} is 7.35595771210779e-05
# The stock price in step {273} is 7.374370612924029e-05
# The stock price in step {274} is 7.392829603580605e-05
# The stock price in step {275} is 7.411334799446266e-05
# The stock price in step {276} is 7.429886316178551e-05
# The stock price in step {277} is 7.448484269724498e-05
# The stock price in step {278} is 7.467128776321376e-05
# The stock price in step {279} is 7.485819952497415e-05
# The stock price in step {280} is 7.504557915072523e-05
# The stock price in step {281} is 7.52334278115903e-05
# The stock price in step {282} is 7.542174668162409e-05
# The stock price in step {283} is 7.561053693782016e-05
# The stock price in step {284} is 7.579979976011822e-05
# The stock price in step {285} is 7.598953633141153e-05
# The stock price in step {286} is 7.617974783755427e-05
# The stock price in step {287} is 7.637043546736897e-05
# The stock price in step {288} is 7.656160041265394e-05
# The stock price in step {289} is 7.675324386819071e-05
# The stock price in step {290} is 7.694536703175151e-05
# The stock price in step {291} is 7.713797110410673e-05
# The stock price in step {292} is 7.733105728903245e-05
# The stock price in step {293} is 7.752462679331797e-05
# The stock price in step {294} is 7.77186808267733e-05
# The stock price in step {295} is 7.791322060223678e-05
# The stock price in step {296} is 7.810824733558264e-05
# The stock price in step {297} is 7.830376224572863e-05
# The stock price in step {298} is 7.849976655464354e-05
# The stock price in step {299} is 7.869626148735496e-05
# The stock price in step {300} is 7.889324827195683e-05
# The stock price in step {301} is 7.909072813961722e-05
# The stock price in step {302} is 7.928870232458594e-05
# The stock price in step {303} is 7.94871720642023e-05
# The stock price in step {304} is 7.96861385989028e-05
# The stock price in step {305} is 7.988560317222895e-05
# The stock price in step {306} is 8.008556703083495e-05
# The stock price in step {307} is 8.02860314244956e-05
# The stock price in step {308} is 8.0486997606114e-05
# The stock price in step {309} is 8.068846683172943e-05
# The stock price in step {310} is 8.089044036052522e-05
# The stock price in step {311} is 8.109291945483658e-05
# The stock price in step {312} is 8.129590538015851e-05
# The stock price in step {313} is 8.14993994051537e-05
# The stock price in step {314} is 8.170340280166046e-05
# The stock price in step {315} is 8.19079168447007e-05
# The stock price in step {316} is 8.211294281248786e-05
# The stock price in step {317} is 8.231848198643487e-05
# The stock price in step {318} is 8.252453565116227e-05
# The stock price in step {319} is 8.273110509450613e-05
# The stock price in step {320} is 8.293819160752613e-05
# The stock price in step {321} is 8.314579648451366e-05
# The stock price in step {322} is 8.335392102299988e-05
# The stock price in step {323} is 8.356256652376382e-05
# The stock price in step {324} is 8.377173429084056e-05
# The stock price in step {325} is 8.39814256315293e-05
# The stock price in step {326} is 8.419164185640161e-05
# The stock price in step {327} is 8.44023842793096e-05
# The stock price in step {328} is 8.461365421739407e-05
# The stock price in step {329} is 8.482545299109283e-05
# The stock price in step {330} is 8.503778192414892e-05
# The stock price in step {331} is 8.525064234361885e-05
# The stock price in step {332} is 8.546403557988093e-05
# The stock price in step {333} is 8.567796296664359e-05
# The stock price in step {334} is 8.58924258409537e-05
# The stock price in step {335} is 8.61074255432049e-05
# The stock price in step {336} is 8.632296341714605e-05
# The stock price in step {337} is 8.653904080988954e-05
# The stock price in step {338} is 8.675565907191982e-05
# The stock price in step {339} is 8.69728195571017e-05
# The stock price in step {340} is 8.719052362268893e-05
# The stock price in step {341} is 8.740877262933262e-05
# The stock price in step {342} is 8.762756794108978e-05
# The stock price in step {343} is 8.784691092543182e-05
# The stock price in step {344} is 8.80668029532531e-05
# The stock price in step {345} is 8.828724539887951e-05
# The stock price in step {346} is 8.850823964007707e-05
# The stock price in step {347} is 8.872978705806049e-05
# The stock price in step {348} is 8.895188903750186e-05
# The stock price in step {349} is 8.917454696653926e-05
# The stock price in step {350} is 8.939776223678549e-05
# The stock price in step {351} is 8.96215362433367e-05
# The stock price in step {352} is 8.984587038478117e-05
# The stock price in step {353} is 9.007076606320801e-05
# The stock price in step {354} is 9.029622468421595e-05
# The stock price in step {355} is 9.05222476569221e-05
# The stock price in step {356} is 9.074883639397076e-05
# The stock price in step {357} is 9.097599231154229e-05
# The stock price in step {358} is 9.120371682936193e-05
# The stock price in step {359} is 9.143201137070863e-05
# The stock price in step {360} is 9.166087736242403e-05
# The stock price in step {361} is 9.189031623492132e-05
# The stock price in step {362} is 9.212032942219421e-05
# The stock price in step {363} is 9.235091836182586e-05
# The stock price in step {364} is 9.258208449499787e-05
# The stock price in step {365} is 9.281382926649938e-05
# The stock price in step {366} is 9.304615412473591e-05
# The stock price in step {367} is 9.327906052173861e-05
# The stock price in step {368} is 9.351254991317321e-05
# The stock price in step {369} is 9.374662375834918e-05
# The stock price in step {370} is 9.39812835202288e-05
# The stock price in step {371} is 9.421653066543635e-05
# The stock price in step {372} is 9.445236666426725e-05
# The stock price in step {373} is 9.468879299069728e-05
# The stock price in step {374} is 9.492581112239172e-05
# The stock price in step {375} is 9.516342254071468e-05
# The stock price in step {376} is 9.540162873073829e-05
# The stock price in step {377} is 9.564043118125202e-05
# The stock price in step {378} is 9.587983138477197e-05
# The stock price in step {379} is 9.61198308375502e-05
# The stock price in step {380} is 9.636043103958404e-05
# The stock price in step {381} is 9.660163349462555e-05
# The stock price in step {382} is 9.684343971019085e-05
# The stock price in step {383} is 9.708585119756958e-05
# The stock price in step {384} is 9.732886947183435e-05
# The stock price in step {385} is 9.757249605185013e-05
# The stock price in step {386} is 9.781673246028386e-05
# The stock price in step {387} is 9.806158022361387e-05
# The stock price in step {388} is 9.830704087213951e-05
# The stock price in step {389} is 9.85531159399906e-05
# The stock price in step {390} is 9.879980696513713e-05
# The stock price in step {391} is 9.90471154893988e-05
# The stock price in step {392} is 9.92950430584547e-05
# The stock price in step {393} is 9.954359122185295e-05
# The stock price in step {394} is 9.979276153302037e-05
# The stock price in step {395} is 0.00010004255554927221
# The stock price in step {396} is 0.00010029297483182188
# The stock price in step {397} is 0.00010054402094579075
# The stock price in step {398} is 0.0001007956954602178
# The stock price in step {399} is 0.00010104799994806959
# The stock price in step {400} is 0.00010130093598625
# The stock price in step {401} is 0.00010155450515561007
# The stock price in step {402} is 0.00010180870904095796
# The stock price in step {403} is 0.00010206354923106875
# The stock price in step {404} is 0.00010231902731869447
# The stock price in step {405} is 0.00010257514490057402
# The stock price in step {406} is 0.00010283190357744308
# The stock price in step {407} is 0.00010308930495404425
# The stock price in step {408} is 0.00010334735063913696
# The stock price in step {409} is 0.00010360604224550759
# The stock price in step {410} is 0.0001038653813899795
# The stock price in step {411} is 0.00010412536969342321
# The stock price in step {412} is 0.00010438600878076645
# The stock price in step {413} is 0.00010464730028100437
# The stock price in step {414} is 0.0001049092458272097
# The stock price in step {415} is 0.00010517184705654294
# The stock price in step {416} is 0.00010543510561026264
# The stock price in step {417} is 0.00010569902313373561
# The stock price in step {418} is 0.00010596360127644725
# The stock price in step {419} is 0.00010622884169201181
# The stock price in step {420} is 0.00010649474603818273
# The stock price in step {421} is 0.00010676131597686305
# The stock price in step {422} is 0.00010702855317411576
# The stock price in step {423} is 0.00010729645930017421
# The stock price in step {424} is 0.00010756503602945255
# The stock price in step {425} is 0.00010783428504055622
# The stock price in step {426} is 0.00010810420801629243
# The stock price in step {427} is 0.00010837480664368065
# The stock price in step {428} is 0.00010864608261396317
# The stock price in step {429} is 0.00010891803762261569
# The stock price in step {430} is 0.0001091906733693579
# The stock price in step {431} is 0.00010946399155816411
# The stock price in step {432} is 0.00010973799389727389
# The stock price in step {433} is 0.00011001268209920274
# The stock price in step {434} is 0.00011028805788075283
# The stock price in step {435} is 0.00011056412296302368
# The stock price in step {436} is 0.00011084087907142296
# The stock price in step {437} is 0.00011111832793567725
# The stock price in step {438} is 0.00011139647128984283
# The stock price in step {439} is 0.00011167531087231661
# The stock price in step {440} is 0.00011195484842584686
# The stock price in step {441} is 0.00011223508569754422
# The stock price in step {442} is 0.00011251602443889254
# The stock price in step {443} is 0.00011279766640575986
# The stock price in step {444} is 0.0001130800133584094
# The stock price in step {445} is 0.00011336306706151052
# The stock price in step {446} is 0.0001136468292841498
# The stock price in step {447} is 0.00011393130179984205
# The stock price in step {448} is 0.00011421648638654141
# The stock price in step {449} is 0.00011450238482665249
# The stock price in step {450} is 0.00011478899890704147
# The stock price in step {451} is 0.00011507633041904729
# The stock price in step {452} is 0.00011536438115849282
# The stock price in step {453} is 0.00011565315292569613
# The stock price in step {454} is 0.00011594264752548169
# The stock price in step {455} is 0.00011623286676719169
# The stock price in step {456} is 0.00011652381246469736
# The stock price in step {457} is 0.00011681548643641025
# The stock price in step {458} is 0.00011710789050529363
# The stock price in step {459} is 0.00011740102649887387
# The stock price in step {460} is 0.0001176948962492519
# The stock price in step {461} is 0.0001179895015931146
# The stock price in step {462} is 0.00011828484437174634
# The stock price in step {463} is 0.00011858092643104045
# The stock price in step {464} is 0.00011887774962151075
# The stock price in step {465} is 0.00011917531579830317
# The stock price in step {466} is 0.00011947362682120726
# The stock price in step {467} is 0.00011977268455466789
# The stock price in step {468} is 0.00012007249086779687
# The stock price in step {469} is 0.00012037304763438464
# The stock price in step {470} is 0.00012067435673291197
# The stock price in step {471} is 0.0001209764200465617
# The stock price in step {472} is 0.00012127923946323052
# The stock price in step {473} is 0.00012158281687554079
# The stock price in step {474} is 0.0001218871541808523
# The stock price in step {475} is 0.0001221922532812742
# The stock price in step {476} is 0.00012249811608367687
# The stock price in step {477} is 0.00012280474449970384
# The stock price in step {478} is 0.00012311214044578367
# The stock price in step {479} is 0.00012342030584314205
# The stock price in step {480} is 0.0001237292426178137
# The stock price in step {481} is 0.00012403895270065446
# The stock price in step {482} is 0.00012434943802735337
# The stock price in step {483} is 0.00012466070053844476
# The stock price in step {484} is 0.0001249727421793203
# The stock price in step {485} is 0.0001252855649002413
# The stock price in step {486} is 0.00012559917065635073
# The stock price in step {487} is 0.00012591356140768562
# The stock price in step {488} is 0.00012622873911918918
# The stock price in step {489} is 0.00012654470576072314
# The stock price in step {490} is 0.00012686146330708004
# The stock price in step {491} is 0.00012717901373799557
# The stock price in step {492} is 0.00012749735903816095
# The stock price in step {493} is 0.00012781650119723535
# The stock price in step {494} is 0.0001281364422098583
# The stock price in step {495} is 0.0001284571840756622
# The stock price in step {496} is 0.0001287787287992847
# The stock price in step {497} is 0.0001291010783903814
# The stock price in step {498} is 0.0001294242348636383
# The stock price in step {499} is 0.0001297482002387844
# The stock price in step {500} is 0.00013007297654060433
# The stock price in step {501} is 0.0001303985657989511
# The stock price in step {502} is 0.00013072497004875853
# The stock price in step {503} is 0.0001310521913300543
# The stock price in step {504} is 0.00013138023168797252
# The stock price in step {505} is 0.00013170909317276647
# The stock price in step {506} is 0.00013203877783982148
# The stock price in step {507} is 0.00013236928774966778
# The stock price in step {508} is 0.0001327006249679934
# The stock price in step {509} is 0.00013303279156565704
# The stock price in step {510} is 0.00013336578961870105
# The stock price in step {511} is 0.0001336996212083643
# The stock price in step {512} is 0.00013403428842109533
# The stock price in step {513} is 0.0001343697933485653
# The stock price in step {514} is 0.0001347061380876811
# The stock price in step {515} is 0.00013504332474059845
# The stock price in step {516} is 0.000135381355414735
# The stock price in step {517} is 0.0001357202322227836
# The stock price in step {518} is 0.00013605995728272537
# The stock price in step {519} is 0.00013640053271784307
# The stock price in step {520} is 0.0001367419606567343
# The stock price in step {521} is 0.00013708424323332472
# The stock price in step {522} is 0.0001374273825868816
# The stock price in step {523} is 0.00013777138086202702
# The stock price in step {524} is 0.0001381162402087513
# The stock price in step {525} is 0.00013846196278242647
# The stock price in step {526} is 0.00013880855074381977
# The stock price in step {527} is 0.00013915600625910704
# The stock price in step {528} is 0.00013950433149988642
# The stock price in step {529} is 0.00013985352864319178
# The stock price in step {530} is 0.00014020359987150643
# The stock price in step {531} is 0.00014055454737277667
# The stock price in step {532} is 0.00014090637334042552
# The stock price in step {533} is 0.00014125907997336644
# The stock price in step {534} is 0.00014161266947601702
# The stock price in step {535} is 0.0001419671440583128
# The stock price in step {536} is 0.0001423225059357211
# The stock price in step {537} is 0.00014267875732925473
# The stock price in step {538} is 0.00014303590046548615
# The stock price in step {539} is 0.00014339393757656108
# The stock price in step {540} is 0.00014375287090021265
# The stock price in step {541} is 0.0001441127026797753
# The stock price in step {542} is 0.00014447343516419878
# The stock price in step {543} is 0.00014483507060806234
# The stock price in step {544} is 0.0001451976112715887
# The stock price in step {545} is 0.00014556105942065812
# The stock price in step {546} is 0.00014592541732682277
# The stock price in step {547} is 0.0001462906872673207
# The stock price in step {548} is 0.00014665687152509027
# The stock price in step {549} is 0.00014702397238878427
# The stock price in step {550} is 0.00014739199215278433
# The stock price in step {551} is 0.00014776093311721512
# The stock price in step {552} is 0.00014813079758795887
# The stock price in step {553} is 0.00014850158787666976
# The stock price in step {554} is 0.00014887330630078828
# The stock price in step {555} is 0.00014924595518355578
# The stock price in step {556} is 0.000149619536854029
# The stock price in step {557} is 0.0001499940536470946
# The stock price in step {558} is 0.00015036950790348378
# The stock price in step {559} is 0.00015074590196978684
# The stock price in step {560} is 0.00015112323819846792
# The stock price in step {561} is 0.00015150151894787966
# The stock price in step {562} is 0.000151880746582278
# The stock price in step {563} is 0.00015226092347183688
# The stock price in step {564} is 0.0001526420519926631
# The stock price in step {565} is 0.0001530241345268112
# The stock price in step {566} is 0.00015340717346229817
# The stock price in step {567} is 0.00015379117119311865
# The stock price in step {568} is 0.00015417613011925972
# The stock price in step {569} is 0.00015456205264671591
# The stock price in step {570} is 0.00015494894118750428
# The stock price in step {571} is 0.00015533679815967947
# The stock price in step {572} is 0.0001557256259873488
# The stock price in step {573} is 0.00015611542710068746
# The stock price in step {574} is 0.0001565062039359537
# The stock price in step {575} is 0.000156897958935504
# The stock price in step {576} is 0.0001572906945478084
# The stock price in step {577} is 0.00015768441322746573
# The stock price in step {578} is 0.000158079117435219
# The stock price in step {579} is 0.00015847480963797084
# The stock price in step {580} is 0.00015887149230879878
# The stock price in step {581} is 0.0001592691679269708
# The stock price in step {582} is 0.00015966783897796084
# The stock price in step {583} is 0.00016006750795346424
# The stock price in step {584} is 0.0001604681773514134
# The stock price in step {585} is 0.00016086984967599336
# The stock price in step {586} is 0.00016127252743765747
# The stock price in step {587} is 0.00016167621315314303
# The stock price in step {588} is 0.0001620809093454871
# The stock price in step {589} is 0.00016248661854404217
# The stock price in step {590} is 0.0001628933432844921
# The stock price in step {591} is 0.00016330108610886776
# The stock price in step {592} is 0.0001637098495655632
# The stock price in step {593} is 0.00016411963620935132
# The stock price in step {594} is 0.0001645304486014
# The stock price in step {595} is 0.00016494228930928804
# The stock price in step {596} is 0.0001653551609070212
# The stock price in step {597} is 0.00016576906597504825
# The stock price in step {598} is 0.00016618400710027728
# The stock price in step {599} is 0.00016659998687609164
# The stock price in step {600} is 0.0001670170079023663
# The stock price in step {601} is 0.00016743507278548403
# The stock price in step {602} is 0.0001678541841383517
# The stock price in step {603} is 0.00016827434458041663
# The stock price in step {604} is 0.00016869555673768296
# The stock price in step {605} is 0.00016911782324272804
# The stock price in step {606} is 0.0001695411467347189
# The stock price in step {607} is 0.00016996552985942874
# The stock price in step {608} is 0.00017039097526925349
# The stock price in step {609} is 0.00017081748562322832
# The stock price in step {610} is 0.00017124506358704434
# The stock price in step {611} is 0.00017167371183306524
# The stock price in step {612} is 0.00017210343304034393
# The stock price in step {613} is 0.00017253422989463933
# The stock price in step {614} is 0.00017296610508843325
# The stock price in step {615} is 0.000173399061320947
# The stock price in step {616} is 0.00017383310129815842
# The stock price in step {617} is 0.00017426822773281884
# The stock price in step {618} is 0.00017470444334446986
# The stock price in step {619} is 0.0001751417508594605
# The stock price in step {620} is 0.0001755801530109641
# The stock price in step {621} is 0.0001760196525389956
# The stock price in step {622} is 0.00017646025219042843
# The stock price in step {623} is 0.0001769019547190119
# The stock price in step {624} is 0.00017734476288538818
# The stock price in step {625} is 0.0001777886794571098
# The stock price in step {626} is 0.00017823370720865676
# The stock price in step {627} is 0.00017867984892145397
# The stock price in step {628} is 0.00017912710738388857
# The stock price in step {629} is 0.00017957548539132743
# The stock price in step {630} is 0.00018002498574613452
# The stock price in step {631} is 0.00018047561125768854
# The stock price in step {632} is 0.00018092736474240042
# The stock price in step {633} is 0.00018138024902373092
# The stock price in step {634} is 0.00018183426693220824
# The stock price in step {635} is 0.0001822894213054458
# The stock price in step {636} is 0.0001827457149881599
# The stock price in step {637} is 0.00018320315083218753
# The stock price in step {638} is 0.00018366173169650425
# The stock price in step {639} is 0.00018412146044724192
# The stock price in step {640} is 0.00018458233995770674
# The stock price in step {641} is 0.00018504437310839716
# The stock price in step {642} is 0.00018550756278702186
# The stock price in step {643} is 0.00018597191188851785
# The stock price in step {644} is 0.0001864374233150685
# The stock price in step {645} is 0.00018690409997612178
# The stock price in step {646} is 0.00018737194478840832
# The stock price in step {647} is 0.00018784096067595973
# The stock price in step {648} is 0.0001883111505701268
# The stock price in step {649} is 0.00018878251740959794
# The stock price in step {650} is 0.00018925506414041741
# The stock price in step {651} is 0.00018972879371600382
# The stock price in step {652} is 0.00019020370909716858
# The stock price in step {653} is 0.00019067981325213433
# The stock price in step {654} is 0.00019115710915655363
# The stock price in step {655} is 0.0001916355997935274
# The stock price in step {656} is 0.00019211528815362368
# The stock price in step {657} is 0.0001925961772348963
# The stock price in step {658} is 0.00019307827004290363
# The stock price in step {659} is 0.0001935615695907272
# The stock price in step {660} is 0.0001940460788989908
# The stock price in step {661} is 0.00019453180099587917
# The stock price in step {662} is 0.00019501873891715702
# The stock price in step {663} is 0.00019550689570618793
# The stock price in step {664} is 0.0001959962744139534
# The stock price in step {665} is 0.000196486878099072
# The stock price in step {666} is 0.0001969787098278183
# The stock price in step {667} is 0.00019747177267414223
# The stock price in step {668} is 0.0001979660697196882
# The stock price in step {669} is 0.00019846160405381433
# The stock price in step {670} is 0.00019895837877361184
# The stock price in step {671} is 0.0001994563969839243
# The stock price in step {672} is 0.0001999556617973672
# The stock price in step {673} is 0.00020045617633434725
# The stock price in step {674} is 0.0002009579437230819
# The stock price in step {675} is 0.000201460967099619
# The stock price in step {676} is 0.00020196524960785624
# The stock price in step {677} is 0.00020247079439956098
# The stock price in step {678} is 0.0002029776046343898
# The stock price in step {679} is 0.00020348568347990832
# The stock price in step {680} is 0.00020399503411161097
# The stock price in step {681} is 0.0002045056597129409
# The stock price in step {682} is 0.0002050175634753097
# The stock price in step {683} is 0.00020553074859811762
# The stock price in step {684} is 0.0002060452182887733
# The stock price in step {685} is 0.00020656097576271404
# The stock price in step {686} is 0.00020707802424342568
# The stock price in step {687} is 0.00020759636696246294
# The stock price in step {688} is 0.00020811600715946947
# The stock price in step {689} is 0.00020863694808219822
# The stock price in step {690} is 0.00020915919298653164
# The stock price in step {691} is 0.00020968274513650208
# The stock price in step {692} is 0.00021020760780431216
# The stock price in step {693} is 0.00021073378427035529
# The stock price in step {694} is 0.0002112612778232361
# The stock price in step {695} is 0.00021179009175979099
# The stock price in step {696} is 0.00021232022938510884
# The stock price in step {697} is 0.00021285169401255146
# The stock price in step {698} is 0.00021338448896377456
# The stock price in step {699} is 0.0002139186175687483
# The stock price in step {700} is 0.00021445408316577816
# The stock price in step {701} is 0.00021499088910152594
# The stock price in step {702} is 0.00021552903873103043
# The stock price in step {703} is 0.00021606853541772858
# The stock price in step {704} is 0.00021660938253347642
# The stock price in step {705} is 0.00021715158345857023
# The stock price in step {706} is 0.00021769514158176753
# The stock price in step {707} is 0.00021824006030030836
# The stock price in step {708} is 0.00021878634301993646
# The stock price in step {709} is 0.00021933399315492066
# The stock price in step {710} is 0.00021988301412807602
# The stock price in step {711} is 0.00022043340937078547
# The stock price in step {712} is 0.00022098518232302103
# The stock price in step {713} is 0.00022153833643336548
# The stock price in step {714} is 0.00022209287515903377
# The stock price in step {715} is 0.00022264880196589477
# The stock price in step {716} is 0.00022320612032849282
# The stock price in step {717} is 0.00022376483373006951
# The stock price in step {718} is 0.00022432494566258543
# The stock price in step {719} is 0.00022488645962674195
# The stock price in step {720} is 0.0002254493791320032
# The stock price in step {721} is 0.0002260137076966179
# The stock price in step {722} is 0.00022657944884764143
# The stock price in step {723} is 0.00022714660612095782
# The stock price in step {724} is 0.0002277151830613019
# The stock price in step {725} is 0.00022828518322228137
# The stock price in step {726} is 0.00022885661016639906
# The stock price in step {727} is 0.0002294294674650753
# The stock price in step {728} is 0.00023000375869867002
# The stock price in step {729} is 0.0002305794874565053
# The stock price in step {730} is 0.0002311566573368878
# The stock price in step {731} is 0.0002317352719471311
# The stock price in step {732} is 0.00023231533490357842
# The stock price in step {733} is 0.00023289684983162512
# The stock price in step {734} is 0.0002334798203657414
# The stock price in step {735} is 0.000234064250149495
# The stock price in step {736} is 0.00023465014283557397
# The stock price in step {737} is 0.0002352375020858095
# The stock price in step {738} is 0.0002358263315711988
# The stock price in step {739} is 0.00023641663497192807
# The stock price in step {740} is 0.00023700841597739552
# The stock price in step {741} is 0.00023760167828623433
# The stock price in step {742} is 0.00023819642560633585
# The stock price in step {743} is 0.0002387926616548728
# The stock price in step {744} is 0.00023939039015832245
# The stock price in step {745} is 0.00023998961485248983
# The stock price in step {746} is 0.00024059033948253125
# The stock price in step {747} is 0.0002411925678029776
# The stock price in step {748} is 0.00024179630357775786
# The stock price in step {749} is 0.00024240155058022258
# The stock price in step {750} is 0.0002430083125931675
# The stock price in step {751} is 0.00024361659340885717
# The stock price in step {752} is 0.0002442263968290487
# The stock price in step {753} is 0.0002448377266650154
# The stock price in step {754} is 0.0002454505867375708
# The stock price in step {755} is 0.0002460649808770922
# The stock price in step {756} is 0.0002466809129235451
# The stock price in step {757} is 0.00024729838672650685
# The stock price in step {758} is 0.00024791740614519056
# The stock price in step {759} is 0.0002485379750484697
# The stock price in step {760} is 0.00024916009731490197
# The stock price in step {761} is 0.00024978377683275356
# The stock price in step {762} is 0.0002504090175000234
# The stock price in step {763} is 0.00025103582322446775
# The stock price in step {764} is 0.0002516641979236244
# The stock price in step {765} is 0.0002522941455248373
# The stock price in step {766} is 0.00025292566996528104
# The stock price in step {767} is 0.0002535587751919854
# The stock price in step {768} is 0.0002541934651618601
# The stock price in step {769} is 0.0002548297438417195
# The stock price in step {770} is 0.0002554676152083074
# The stock price in step {771} is 0.000256107083248322
# The stock price in step {772} is 0.00025674815195844057
# The stock price in step {773} is 0.0002573908253453446
# The stock price in step {774} is 0.00025803510742574494
# The stock price in step {775} is 0.00025868100222640664
# The stock price in step {776} is 0.00025932851378417435
# The stock price in step {777} is 0.0002599776461459974
# The stock price in step {778} is 0.0002606284033689551
# The stock price in step {779} is 0.00026128078952028223
# The stock price in step {780} is 0.0002619348086773944
# The stock price in step {781} is 0.00026259046492791343
# The stock price in step {782} is 0.00026324776236969307
# The stock price in step {783} is 0.0002639067051108445
# The stock price in step {784} is 0.00026456729726976187
# The stock price in step {785} is 0.0002652295429751484
# The stock price in step {786} is 0.00026589344636604196
# The stock price in step {787} is 0.0002665590115918408
# The stock price in step {788} is 0.0002672262428123298
# The stock price in step {789} is 0.0002678951441977063
# The stock price in step {790} is 0.00026856571992860606
# The stock price in step {791} is 0.0002692379741961296
# The stock price in step {792} is 0.00026991191120186836
# The stock price in step {793} is 0.0002705875351579307
# The stock price in step {794} is 0.0002712648502869686
# The stock price in step {795} is 0.0002719438608222038
# The stock price in step {796} is 0.0002726245710074544
# The stock price in step {797} is 0.00027330698509716125
# The stock price in step {798} is 0.00027399110735641457
# The stock price in step {799} is 0.00027467694206098083
# The stock price in step {800} is 0.00027536449349732905
# The stock price in step {801} is 0.00027605376596265805
# The stock price in step {802} is 0.0002767447637649229
# The stock price in step {803} is 0.00027743749122286214
# The stock price in step {804} is 0.0002781319526660246
# The stock price in step {805} is 0.00027882815243479667
# The stock price in step {806} is 0.0002795260948804291
# The stock price in step {807} is 0.00028022578436506443
# The stock price in step {808} is 0.00028092722526176425
# The stock price in step {809} is 0.0002816304219545364
# The stock price in step {810} is 0.0002823353788383626
# The stock price in step {811} is 0.00028304210031922553
# The stock price in step {812} is 0.00028375059081413686
# The stock price in step {813} is 0.00028446085475116443
# The stock price in step {814} is 0.00028517289656946015
# The stock price in step {815} is 0.00028588672071928775
# The stock price in step {816} is 0.0002866023316620505
# The stock price in step {817} is 0.000287319733870319
# The stock price in step {818} is 0.00028803893182785957
# The stock price in step {819} is 0.00028875993002966166
# The stock price in step {820} is 0.00028948273298196644
# The stock price in step {821} is 0.00029020734520229465
# The stock price in step {822} is 0.00029093377121947506
# The stock price in step {823} is 0.0002916620155736726
# The stock price in step {824} is 0.00029239208281641696
# The stock price in step {825} is 0.00029312397751063066
# The stock price in step {826} is 0.000293857704230658
# The stock price in step {827} is 0.00029459326756229334
# The stock price in step {828} is 0.00029533067210280994
# The stock price in step {829} is 0.00029606992246098855
# The stock price in step {830} is 0.00029681102325714633
# The stock price in step {831} is 0.0002975539791231656
# The stock price in step {832} is 0.00029829879470252304
# The stock price in step {833} is 0.00029904547465031835
# The stock price in step {834} is 0.0002997940236333037
# The stock price in step {835} is 0.0003005444463299126
# The stock price in step {836} is 0.0003012967474302895
# The stock price in step {837} is 0.00030205093163631854
# The stock price in step {838} is 0.0003028070036616536
# The stock price in step {839} is 0.0003035649682317472
# The stock price in step {840} is 0.0003043248300838804
# The stock price in step {841} is 0.0003050865939671923
# The stock price in step {842} is 0.0003058502646427096
# The stock price in step {843} is 0.0003066158468833765
# The stock price in step {844} is 0.00030738334547408456
# The stock price in step {845} is 0.0003081527652117024
# The stock price in step {846} is 0.0003089241109051059
# The stock price in step {847} is 0.00030969738737520824
# The stock price in step {848} is 0.0003104725994549898
# The stock price in step {849} is 0.0003112497519895286
# The stock price in step {850} is 0.0003120288498360305
# The stock price in step {851} is 0.0003128098978638596
# The stock price in step {852} is 0.0003135929009545686
# The stock price in step {853} is 0.0003143778640019294
# The stock price in step {854} is 0.00031516479191196357
# The stock price in step {855} is 0.0003159536896029731
# The stock price in step {856} is 0.00031674456200557114
# The stock price in step {857} is 0.0003175374140627128
# The stock price in step {858} is 0.000318332250729726
# The stock price in step {859} is 0.0003191290769743425
# The stock price in step {860} is 0.0003199278977767289
# The stock price in step {861} is 0.00032072871812951787
# The stock price in step {862} is 0.0003215315430378392
# The stock price in step {863} is 0.0003223363775193512
# The stock price in step {864} is 0.0003231432266042719
# ...
# The euro-style call price at step {9747} is 1425563.9934382245
# The euro-style call price at step {9748} is 1429132.3870553034
# The euro-style call price at step {9749} is 1432709.7128169537
# The euro-style call price at step {9750} is 1436295.9930814728
# The euro-style call price at step {9751} is 1439891.250263124
# The euro-style call price at step {9752} is 1443495.5068322765
# The euro-style call price at step {9753} is 1447108.7853155457
# The euro-style call price at step {9754} is 1450731.1082959338
# The euro-style call price at step {9755} is 1454362.4984129712
# The euro-style call price at step {9756} is 1458002.978362858
# The euro-style call price at step {9757} is 1461652.5708986057
# The euro-style call price at step {9758} is 1465311.2988301797
# The euro-style call price at step {9759} is 1468979.1850246412
# The euro-style call price at step {9760} is 1472656.252406291
# The euro-style call price at step {9761} is 1476342.5239568122
# The euro-style call price at step {9762} is 1480038.022715414
# The euro-style call price at step {9763} is 1483742.7717789756
# The euro-style call price at step {9764} is 1487456.7943021907
# The euro-style call price at step {9765} is 1491180.1134977122
# The euro-style call price at step {9766} is 1494912.7526362971
# The euro-style call price at step {9767} is 1498654.7350469525
# The euro-style call price at step {9768} is 1502406.0841170803
# The euro-style call price at step {9769} is 1506166.8232926244
# The euro-style call price at step {9770} is 1509936.9760782172
# The euro-style call price at step {9771} is 1513716.5660373257
# The euro-style call price at step {9772} is 1517505.6167923994
# The euro-style call price at step {9773} is 1521304.152025018
# The euro-style call price at step {9774} is 1525112.1954760386
# The euro-style call price at step {9775} is 1528929.7709457458
# The euro-style call price at step {9776} is 1532756.9022939983
# The euro-style call price at step {9777} is 1536593.6134403795
# The euro-style call price at step {9778} is 1540439.928364347
# The euro-style call price at step {9779} is 1544295.871105381
# The euro-style call price at step {9780} is 1548161.4657631365
# The euro-style call price at step {9781} is 1552036.7364975926
# The euro-style call price at step {9782} is 1555921.707529204
# The euro-style call price at step {9783} is 1559816.4031390522
# The euro-style call price at step {9784} is 1563720.8476689977
# The euro-style call price at step {9785} is 1567635.0655218314
# The euro-style call price at step {9786} is 1571559.0811614275
# The euro-style call price at step {9787} is 1575492.9191128968
# The euro-style call price at step {9788} is 1579436.6039627392
# The euro-style call price at step {9789} is 1583390.160358998
# The euro-style call price at step {9790} is 1587353.6130114133
# The euro-style call price at step {9791} is 1591326.986691577
# The euro-style call price at step {9792} is 1595310.3062330873
# The euro-style call price at step {9793} is 1599303.596531705
# The euro-style call price at step {9794} is 1603306.8825455073
# The euro-style call price at step {9795} is 1607320.1892950446
# The euro-style call price at step {9796} is 1611343.541863497
# The euro-style call price at step {9797} is 1615376.9653968315
# The euro-style call price at step {9798} is 1619420.4851039583
# The euro-style call price at step {9799} is 1623474.1262568883
# The euro-style call price at step {9800} is 1627537.9141908924
# The euro-style call price at step {9801} is 1631611.874304658
# The euro-style call price at step {9802} is 1635696.0320604492
# The euro-style call price at step {9803} is 1639790.4129842655
# The euro-style call price at step {9804} is 1643895.0426660008
# The euro-style call price at step {9805} is 1648009.946759604
# The euro-style call price at step {9806} is 1652135.150983239
# The euro-style call price at step {9807} is 1656270.681119446
# The euro-style call price at step {9808} is 1660416.5630153012
# The euro-style call price at step {9809} is 1664572.8225825804
# The euro-style call price at step {9810} is 1668739.4857979193
# The euro-style call price at step {9811} is 1672916.5787029767
# The euro-style call price at step {9812} is 1677104.1274045967
# The euro-style call price at step {9813} is 1681302.1580749722
# The euro-style call price at step {9814} is 1685510.6969518089
# The euro-style call price at step {9815} is 1689729.7703384883
# The euro-style call price at step {9816} is 1693959.4046042324
# The euro-style call price at step {9817} is 1698199.6261842698
# The euro-style call price at step {9818} is 1702450.4615799987
# The euro-style call price at step {9819} is 1706711.9373591545
# The euro-style call price at step {9820} is 1710984.0801559745
# The euro-style call price at step {9821} is 1715266.916671365
# The euro-style call price at step {9822} is 1719560.4736730685
# The euro-style call price at step {9823} is 1723864.77799583
# The euro-style call price at step {9824} is 1728179.8565415654
# The euro-style call price at step {9825} is 1732505.7362795298
# The euro-style call price at step {9826} is 1736842.4442464856
# The euro-style call price at step {9827} is 1741190.007546872
# The euro-style call price at step {9828} is 1745548.4533529733
# The euro-style call price at step {9829} is 1749917.8089050904
# The euro-style call price at step {9830} is 1754298.1015117096
# The euro-style call price at step {9831} is 1758689.3585496736
# The euro-style call price at step {9832} is 1763091.6074643536
# The euro-style call price at step {9833} is 1767504.8757698196
# The euro-style call price at step {9834} is 1771929.1910490128
# The euro-style call price at step {9835} is 1776364.580953918
# The euro-style call price at step {9836} is 1780811.0732057365
# The euro-style call price at step {9837} is 1785268.6955950595
# The euro-style call price at step {9838} is 1789737.4759820416
# The euro-style call price at step {9839} is 1794217.4422965746
# The euro-style call price at step {9840} is 1798708.6225384625
# The euro-style call price at step {9841} is 1803211.0447775964
# The euro-style call price at step {9842} is 1807724.73715413
# The euro-style call price at step {9843} is 1812249.7278786553
# The euro-style call price at step {9844} is 1816786.0452323793
# The euro-style call price at step {9845} is 1821333.7175673
# The euro-style call price at step {9846} is 1825892.7733063844
# The euro-style call price at step {9847} is 1830463.2409437457
# The euro-style call price at step {9848} is 1835045.1490448213
# The euro-style call price at step {9849} is 1839638.5262465521
# The euro-style call price at step {9850} is 1844243.4012575604
# The euro-style call price at step {9851} is 1848859.8028583298
# The euro-style call price at step {9852} is 1853487.7599013858
# The euro-style call price at step {9853} is 1858127.3013114745
# The euro-style call price at step {9854} is 1862778.456085745
# The euro-style call price at step {9855} is 1867441.2532939299
# The euro-style call price at step {9856} is 1872115.7220785266
# The euro-style call price at step {9857} is 1876801.8916549806
# The euro-style call price at step {9858} is 1881499.7913118668
# The euro-style call price at step {9859} is 1886209.4504110734
# The euro-style call price at step {9860} is 1890930.8983879853
# The euro-style call price at step {9861} is 1895664.1647516673
# The euro-style call price at step {9862} is 1900409.27908505
# The euro-style call price at step {9863} is 1905166.2710451134
# The euro-style call price at step {9864} is 1909935.1703630725
# The euro-style call price at step {9865} is 1914716.0068445634
# The euro-style call price at step {9866} is 1919508.8103698299
# The euro-style call price at step {9867} is 1924313.6108939098
# The euro-style call price at step {9868} is 1929130.4384468219
# The euro-style call price at step {9869} is 1933959.323133754
# The euro-style call price at step {9870} is 1938800.2951352512
# The euro-style call price at step {9871} is 1943653.384707404
# The euro-style call price at step {9872} is 1948518.6221820384
# The euro-style call price at step {9873} is 1953396.0379669045
# The euro-style call price at step {9874} is 1958285.6625458666
# The euro-style call price at step {9875} is 1963187.526479094
# The euro-style call price at step {9876} is 1968101.6604032528
# The euro-style call price at step {9877} is 1973028.0950316957
# The euro-style call price at step {9878} is 1977966.861154655
# The euro-style call price at step {9879} is 1982917.9896394352
# The euro-style call price at step {9880} is 1987881.5114306058
# The euro-style call price at step {9881} is 1992857.4575501936
# The euro-style call price at step {9882} is 1997845.8590978784
# The euro-style call price at step {9883} is 2002846.747251186
# The euro-style call price at step {9884} is 2007860.1532656837
# The euro-style call price at step {9885} is 2012886.1084751752
# The euro-style call price at step {9886} is 2017924.6442918973
# The euro-style call price at step {9887} is 2022975.7922067149
# The euro-style call price at step {9888} is 2028039.5837893188
# The euro-style call price at step {9889} is 2033116.0506884234
# The euro-style call price at step {9890} is 2038205.224631963
# The euro-style call price at step {9891} is 2043307.1374272914
# The euro-style call price at step {9892} is 2048421.82096138
# The euro-style call price at step {9893} is 2053549.3072010176
# The euro-style call price at step {9894} is 2058689.62819301
# The euro-style call price at step {9895} is 2063842.8160643803
# The euro-style call price at step {9896} is 2069008.9030225694
# The euro-style call price at step {9897} is 2074187.9213556373
# The euro-style call price at step {9898} is 2079379.9034324656
# The euro-style call price at step {9899} is 2084584.881702959
# The euro-style call price at step {9900} is 2089802.8886982491
# The euro-style call price at step {9901} is 2095033.9570308963
# The euro-style call price at step {9902} is 2100278.1193950945
# The euro-style call price at step {9903} is 2105535.408566876
# The euro-style call price at step {9904} is 2110805.8574043154
# The euro-style call price at step {9905} is 2116089.4988477346
# The euro-style call price at step {9906} is 2121386.36591991
# The euro-style call price at step {9907} is 2126696.4917262774
# The euro-style call price at step {9908} is 2132019.9094551415
# The euro-style call price at step {9909} is 2137356.6523778797
# The euro-style call price at step {9910} is 2142706.753849153
# The euro-style call price at step {9911} is 2148070.2473071124
# The euro-style call price at step {9912} is 2153447.16627361
# The euro-style call price at step {9913} is 2158837.544354407
# The euro-style call price at step {9914} is 2164241.415239384
# The euro-style call price at step {9915} is 2169658.812702751
# The euro-style call price at step {9916} is 2175089.77060326
# The euro-style call price at step {9917} is 2180534.322884416
# The euro-style call price at step {9918} is 2185992.5035746885
# The euro-style call price at step {9919} is 2191464.3467877232
# The euro-style call price at step {9920} is 2196949.8867225596
# The euro-style call price at step {9921} is 2202449.15766384
# The euro-style call price at step {9922} is 2207962.1939820247
# The euro-style call price at step {9923} is 2213489.030133609
# The euro-style call price at step {9924} is 2219029.7006613375
# The euro-style call price at step {9925} is 2224584.2401944185
# The euro-style call price at step {9926} is 2230152.683448742
# The euro-style call price at step {9927} is 2235735.065227097
# The euro-style call price at step {9928} is 2241331.4204193875
# The euro-style call price at step {9929} is 2246941.7840028517
# The euro-style call price at step {9930} is 2252566.1910422803
# The euro-style call price at step {9931} is 2258204.676690235
# The euro-style call price at step {9932} is 2263857.27618727
# The euro-style call price at step {9933} is 2269524.0248621507
# The euro-style call price at step {9934} is 2275204.9581320747
# The euro-style call price at step {9935} is 2280900.1115028933
# The euro-style call price at step {9936} is 2286609.5205693333
# The euro-style call price at step {9937} is 2292333.2210152205
# The euro-style call price at step {9938} is 2298071.248613701
# The euro-style call price at step {9939} is 2303823.6392274667
# The euro-style call price at step {9940} is 2309590.4288089764
# The euro-style call price at step {9941} is 2315371.6534006847
# The euro-style call price at step {9942} is 2321167.349135264
# The euro-style call price at step {9943} is 2326977.5522358306
# The euro-style call price at step {9944} is 2332802.299016174
# The euro-style call price at step {9945} is 2338641.62588098
# The euro-style call price at step {9946} is 2344495.5693260604
# The euro-style call price at step {9947} is 2350364.1659385813
# The euro-style call price at step {9948} is 2356247.45239729
# The euro-style call price at step {9949} is 2362145.465472746
# The euro-style call price at step {9950} is 2368058.242027551
# The euro-style call price at step {9951} is 2373985.8190165767
# The euro-style call price at step {9952} is 2379928.2334871995
# The euro-style call price at step {9953} is 2385885.5225795284
# The euro-style call price at step {9954} is 2391857.7235266403
# The euro-style call price at step {9955} is 2397844.8736548102
# The euro-style call price at step {9956} is 2403847.010383746
# The euro-style call price at step {9957} is 2409864.1712268223
# The euro-style call price at step {9958} is 2415896.393791313
# The euro-style call price at step {9959} is 2421943.715778629
# The euro-style call price at step {9960} is 2428006.1749845524
# The euro-style call price at step {9961} is 2434083.8092994737
# The euro-style call price at step {9962} is 2440176.656708626
# The euro-style call price at step {9963} is 2446284.7552923267
# The euro-style call price at step {9964} is 2452408.143226211
# The euro-style call price at step {9965} is 2458546.8587814737
# The euro-style call price at step {9966} is 2464700.9403251065
# The euro-style call price at step {9967} is 2470870.42632014
# The euro-style call price at step {9968} is 2477055.3553258805
# The euro-style call price at step {9969} is 2483255.7659981553
# The euro-style call price at step {9970} is 2489471.6970895515
# The euro-style call price at step {9971} is 2495703.1874496583
# The euro-style call price at step {9972} is 2501950.2760253106
# The euro-style call price at step {9973} is 2508213.001860833
# The euro-style call price at step {9974} is 2514491.404098281
# The euro-style call price at step {9975} is 2520785.5219776905
# The euro-style call price at step {9976} is 2527095.394837318
# The euro-style call price at step {9977} is 2533421.0621138895
# The euro-style call price at step {9978} is 2539762.563342846
# The euro-style call price at step {9979} is 2546119.938158591
# The euro-style call price at step {9980} is 2552493.2262947373
# The euro-style call price at step {9981} is 2558882.467584357
# The euro-style call price at step {9982} is 2565287.7019602293
# The euro-style call price at step {9983} is 2571708.969455089
# The euro-style call price at step {9984} is 2578146.3102018796
# The euro-style call price at step {9985} is 2584599.7644340014
# The euro-style call price at step {9986} is 2591069.372485564
# The euro-style call price at step {9987} is 2597555.174791639
# The euro-style call price at step {9988} is 2604057.2118885126
# The euro-style call price at step {9989} is 2610575.524413937
# The euro-style call price at step {9990} is 2617110.1531073865
# The euro-style call price at step {9991} is 2623661.1388103124
# The euro-style call price at step {9992} is 2630228.5224663964
# The euro-style call price at step {9993} is 2636812.3451218084
# The euro-style call price at step {9994} is 2643412.6479254602
# The euro-style call price at step {9995} is 2650029.4721292667
# The euro-style call price at step {9996} is 2656662.8590884004
# The euro-style call price at step {9997} is 2663312.8502615513
# The euro-style call price at step {9998} is 2669979.487211186
# The euro-style call price at step {9999} is 2676662.8116038074
# The euro-style call price at step {10000} is 2683362.865210214
# The error with  10000 steps is 8.681857786174696e-05
